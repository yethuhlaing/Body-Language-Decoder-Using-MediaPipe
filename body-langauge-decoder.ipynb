# %% [markdown]
# # Installation and Import Dependencies

# %%
# !pip install mediapipe opencv-python pandas scikit-learn
# Out:
# Requirement already satisfied: mediapipe in c:\users\user\anaconda3\lib\site-packages (0.9.0.1)
# Requirement already satisfied: opencv-python in c:\users\user\anaconda3\lib\site-packages (4.7.0.68)
# Requirement already satisfied: pandas in c:\users\user\anaconda3\lib\site-packages (1.4.2)
# Requirement already satisfied: scikit-learn in c:\users\user\anaconda3\lib\site-packages (1.0.2)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\user\anaconda3\lib\site-packages (from mediapipe) (23.1.4)
# Requirement already satisfied: attrs>=19.1.0 in c:\users\user\anaconda3\lib\site-packages (from mediapipe) (21.4.0)
# Requirement already satisfied: opencv-contrib-python in c:\users\user\anaconda3\lib\site-packages (from mediapipe) (4.7.0.68)
# Requirement already satisfied: absl-py in c:\users\user\anaconda3\lib\site-packages (from mediapipe) (1.3.0)
# Requirement already satisfied: numpy in c:\users\user\anaconda3\lib\site-packages (from mediapipe) (1.21.5)
# Requirement already satisfied: protobuf<4,>=3.11 in c:\users\user\anaconda3\lib\site-packages (from mediapipe) (3.19.1)
# Requirement already satisfied: matplotlib in c:\users\user\anaconda3\lib\site-packages (from mediapipe) (3.5.1)
# Requirement already satisfied: pytz>=2020.1 in c:\users\user\anaconda3\lib\site-packages (from pandas) (2021.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\user\anaconda3\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: joblib>=0.11 in c:\users\user\anaconda3\lib\site-packages (from scikit-learn) (1.1.0)
# Requirement already satisfied: scipy>=1.1.0 in c:\users\user\anaconda3\lib\site-packages (from scikit-learn) (1.7.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\user\anaconda3\lib\site-packages (from scikit-learn) (2.2.0)
# Requirement already satisfied: six>=1.5 in c:\users\user\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\user\anaconda3\lib\site-packages (from matplotlib->mediapipe) (9.0.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\user\anaconda3\lib\site-packages (from matplotlib->mediapipe) (21.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\user\anaconda3\lib\site-packages (from matplotlib->mediapipe) (0.11.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\user\anaconda3\lib\site-packages (from matplotlib->mediapipe) (3.0.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\user\anaconda3\lib\site-packages (from matplotlib->mediapipe) (1.3.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\user\anaconda3\lib\site-packages (from matplotlib->mediapipe) (4.25.0)
# [notice] A new release of pip available: 22.3 -> 22.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import mediapipe as mp
import cv2
import os
import numpy as np

# %%
mp_drawing = mp.solutions.drawing_utils
mp_holistic = mp.solutions.holistic

# %% [markdown]
# # Make RealTime WebCam

# %%
cap = cv2.VideoCapture(0)
# Initiate holistic model
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    
    while cap.isOpened():
        ret, frame = cap.read()
        
        # Recolor Feed
        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        #To improve performance, optionally mark the image as not writeable to pass by reference
        image.flags.writeable = False        
        
        # Make Detections
        results = holistic.process(image)
        # print(results.face_landmarks)
        
        # face_landmarks, pose_landmarks, left_hand_landmarks, right_hand_landmarks
        
        # Recolor image back to BGR for rendering
        image.flags.writeable = True   
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
        
        # 1. Draw face landmarks
        mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACEMESH_TESSELATION, 
                                 mp_drawing.DrawingSpec(color=(80,110,10), thickness=1, circle_radius=1),
                                 mp_drawing.DrawingSpec(color=(80,256,121), thickness=1, circle_radius=1)
                                 )
        
        # 2. Right hand
        mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(80,22,10), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(80,44,121), thickness=2, circle_radius=2)
                                 )

        # 3. Left Hand
        mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(121,22,76), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(121,44,250), thickness=2, circle_radius=2)
                                 )

        # 4. Pose Detections
        mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2)
                                 )
                        
        cv2.imshow('Raw Webcam Feed', image)

        if cv2.waitKey(10) & 0xFF == ord('q'):
            break

cap.release()
cv2.destroyAllWindows()

# %%
results.face_landmarks
# Out:
# landmark {
#   x: 0.7755465
#   y: 0.8414613
#   z: -0.03850935
# }
# landmark {
#   x: 0.78027594
#   y: 0.76915973
#   z: -0.074637935
# }
# landmark {
#   x: 0.77588314
#   y: 0.79109
#   z: -0.03890452
# }
# landmark {
#   x: 0.7632823
#   y: 0.70813954
#   z: -0.060104355
# }
# landmark {
#   x: 0.78039813
#   y: 0.74957514
#   z: -0.07984036
# }
# landmark {
#   x: 0.77844095
#   y: 0.72494626
#   z: -0.07526005
# }
# landmark {
#   x: 0.7715396
#   y: 0.66639125
#   z: -0.03941087
# }
# landmark {
#   x: 0.6631838
#   y: 0.6644461
#   z: -0.0013520339
# }
# landmark {
#   x: 0.7695097
#   y: 0.62172186
#   z: -0.03199866
# }
# landmark {
#   x: 0.769731
#   y: 0.595649
#   z: -0.03538855
# }
# landmark {
#   x: 0.7663245
#   y: 0.50347954
#   z: -0.023039933
# }
# landmark {
#   x: 0.77529097
#   y: 0.85166216
#   z: -0.036073793
# }
# landmark {
#   x: 0.7743448
#   y: 0.8590802
#   z: -0.03099377
# }
# landmark {
#   x: 0.7730137
#   y: 0.8616965
#   z: -0.024443563
# }
# landmark {
#   x: 0.7740112
#   y: 0.86929125
#   z: -0.02260781
# }
# landmark {
#   x: 0.7744469
#   y: 0.87815785
#   z: -0.024823023
# }
# landmark {
#   x: 0.77463526
#   y: 0.88926095
#   z: -0.027283128
# }
# landmark {
#   x: 0.77429366
#   y: 0.90144455
#   z: -0.024666624
# }
# landmark {
#   x: 0.7723599
#   y: 0.9203303
#   z: -0.010651063
# }
# landmark {
#   x: 0.7790633
#   y: 0.77932423
#   z: -0.06739358
# }
# landmark {
#   x: 0.76369435
#   y: 0.7785263
#   z: -0.050146222
# }
# landmark {
#   x: 0.59879786
#   y: 0.59186965
#   z: 0.05379715
# }
# landmark {
#   x: 0.7046348
#   y: 0.6788407
#   z: -0.008654236
# }
# landmark {
#   x: 0.6906268
#   y: 0.68079203
#   z: -0.009627475
# }
# landmark {
#   x: 0.67658824
#   y: 0.680291
#   z: -0.0078063183
# }
# landmark {
#   x: 0.6562656
#   y: 0.6710917
#   z: 0.000370941
# }
# landmark {
#   x: 0.7163114
#   y: 0.6735483
#   z: -0.005072121
# }
# landmark {
#   x: 0.6868637
#   y: 0.636112
#   z: -0.019198516
# }
# landmark {
#   x: 0.70107377
#   y: 0.63694525
#   z: -0.015830712
# }
# landmark {
#   x: 0.6727881
#   y: 0.6381895
#   z: -0.016332448
# }
# landmark {
#   x: 0.662726
#   y: 0.6438416
#   z: -0.011325376
# }
# landmark {
#   x: 0.64374244
#   y: 0.68294096
#   z: 0.006262733
# }
# landmark {
#   x: 0.7145411
#   y: 0.95088613
#   z: 0.0008014392
# }
# landmark {
#   x: 0.6575133
#   y: 0.66106594
#   z: 0.0022235706
# }
# landmark {
#   x: 0.5933067
#   y: 0.67525214
#   z: 0.061541315
# }
# landmark {
#   x: 0.6256665
#   y: 0.6701618
#   z: 0.017587844
# }
# landmark {
#   x: 0.69626385
#   y: 0.7575261
#   z: -0.018885825
# }
# landmark {
#   x: 0.7565565
#   y: 0.83801556
#   z: -0.03957052
# }
# landmark {
#   x: 0.75737613
#   y: 0.85858166
#   z: -0.03155628
# }
# landmark {
#   x: 0.7356131
#   y: 0.8434293
#   z: -0.033625323
# }
# landmark {
#   x: 0.72119606
#   y: 0.85071725
#   z: -0.024037296
# }
# landmark {
#   x: 0.7420254
#   y: 0.8592319
#   z: -0.028077327
# }
# landmark {
#   x: 0.7295555
#   y: 0.86026335
#   z: -0.01905027
# }
# landmark {
#   x: 0.70030683
#   y: 0.88187075
#   z: -0.0019653533
# }
# landmark {
#   x: 0.76807433
#   y: 0.76843524
#   z: -0.07501625
# }
# landmark {
#   x: 0.7660357
#   y: 0.74999434
#   z: -0.08015186
# }
# landmark {
#   x: 0.6378348
#   y: 0.6207193
#   z: -0.01130013
# }
# landmark {
#   x: 0.72476065
#   y: 0.70946574
#   z: -0.019042207
# }
# landmark {
#   x: 0.7278832
#   y: 0.7647713
#   z: -0.04605458
# }
# landmark {
#   x: 0.7256359
#   y: 0.75518095
#   z: -0.04217664
# }
# landmark {
#   x: 0.6502841
#   y: 0.75600564
#   z: -0.00783481
# }
# landmark {
#   x: 0.76491165
#   y: 0.7270631
#   z: -0.07301604
# }
# landmark {
#   x: 0.6756994
#   y: 0.5998742
#   z: -0.029641598
# }
# landmark {
#   x: 0.65416634
#   y: 0.6068704
#   z: -0.022032637
# }
# landmark {
#   x: 0.6165345
#   y: 0.5566547
#   z: 0.027545732
# }
# landmark {
#   x: 0.73952216
#   y: 0.61624366
#   z: -0.032522485
# }
# landmark {
#   x: 0.71351403
#   y: 0.6416375
#   z: -0.009551893
# }
# landmark {
#   x: 0.68862164
#   y: 0.8619835
#   z: -0.0014743792
# }
# landmark {
#   x: 0.6048366
#   y: 0.85883635
#   z: 0.109037854
# }
# landmark {
#   x: 0.73859626
#   y: 0.77512133
#   z: -0.038585454
# }
# landmark {
#   x: 0.7515227
#   y: 0.7822502
#   z: -0.03721557
# }
# landmark {
#   x: 0.7041631
#   y: 0.86224794
#   z: -0.0011952254
# }
# landmark {
#   x: 0.71061265
#   y: 0.8612558
#   z: -0.0038960036
# }
# landmark {
#   x: 0.6445497
#   y: 0.5932696
#   z: -0.017019175
# }
# landmark {
#   x: 0.726226
#   y: 0.77381116
#   z: -0.037919797
# }
# landmark {
#   x: 0.70391524
#   y: 0.60156155
#   z: -0.033488095
# }
# landmark {
#   x: 0.70129514
#   y: 0.5848707
#   z: -0.03714905
# }
# landmark {
#   x: 0.6820484
#   y: 0.51075053
#   z: -0.017764471
# }
# landmark {
#   x: 0.6309769
#   y: 0.57399094
#   z: 0.002139764
# }
# landmark {
#   x: 0.6935295
#   y: 0.5462396
#   z: -0.027575823
# }
# landmark {
#   x: 0.6271019
#   y: 0.61199284
#   z: -0.0011788057
# }
# landmark {
#   x: 0.6131929
#   y: 0.60273224
#   z: 0.024838584
# }
# landmark {
#   x: 0.7569313
#   y: 0.850224
#   z: -0.037413694
# }
# landmark {
#   x: 0.73952717
#   y: 0.85304254
#   z: -0.03147946
# }
# landmark {
#   x: 0.72569144
#   y: 0.8557403
#   z: -0.022678846
# }
# landmark {
#   x: 0.7422488
#   y: 0.77923304
#   z: -0.034691304
# }
# landmark {
#   x: 0.70761085
#   y: 0.8620467
#   z: -0.0024907177
# }
# landmark {
#   x: 0.7153817
#   y: 0.8670204
#   z: -0.009577794
# }
# landmark {
#   x: 0.71175504
#   y: 0.8603853
#   z: -0.004099327
# }
# landmark {
#   x: 0.74915195
#   y: 0.76758933
#   z: -0.057892542
# }
# landmark {
#   x: 0.7314229
#   y: 0.8589421
#   z: -0.016496474
# }
# landmark {
#   x: 0.74386275
#   y: 0.859885
#   z: -0.021945141
# }
# landmark {
#   x: 0.75788176
#   y: 0.86087584
#   z: -0.025439851
# }
# landmark {
#   x: 0.7516342
#   y: 0.91946447
#   z: -0.0123674115
# }
# landmark {
#   x: 0.75446564
#   y: 0.89935315
#   z: -0.026554255
# }
# landmark {
#   x: 0.75595874
#   y: 0.8869585
#   z: -0.028738452
# }
# landmark {
#   x: 0.7570896
#   y: 0.87569547
#   z: -0.025976298
# }
# landmark {
#   x: 0.75802374
#   y: 0.8683949
#   z: -0.023736114
# }
# landmark {
#   x: 0.73026675
#   y: 0.864906
#   z: -0.014877117
# }
# landmark {
#   x: 0.7282753
#   y: 0.8674927
#   z: -0.017122433
# }
# landmark {
#   x: 0.724973
#   y: 0.8729969
#   z: -0.018919311
# }
# landmark {
#   x: 0.72202104
#   y: 0.8800763
#   z: -0.016444271
# }
# landmark {
#   x: 0.70863897
#   y: 0.8275118
#   z: -0.021194518
# }
# landmark {
#   x: 0.58720976
#   y: 0.7629096
#   z: 0.12339729
# }
# landmark {
#   x: 0.77749884
#   y: 0.7837136
#   z: -0.048796147
# }
# landmark {
#   x: 0.7216856
#   y: 0.8635985
#   z: -0.008245371
# }
# landmark {
#   x: 0.7189828
#   y: 0.86447793
#   z: -0.009663567
# }
# landmark {
#   x: 0.75679433
#   y: 0.79150796
#   z: -0.037693575
# }
# landmark {
#   x: 0.7306985
#   y: 0.7864599
#   z: -0.025956973
# }
# landmark {
#   x: 0.75435257
#   y: 0.7871292
#   z: -0.037658643
# }
# landmark {
#   x: 0.7091218
#   y: 0.72058856
#   z: -0.015919982
# }
# landmark {
#   x: 0.6854158
#   y: 0.73341006
#   z: -0.014406085
# }
# landmark {
#   x: 0.7223386
#   y: 0.76427776
#   z: -0.03411393
# }
# landmark {
#   x: 0.64333975
#   y: 0.5287819
#   z: 0.002056299
# }
# landmark {
#   x: 0.6566445
#   y: 0.5540833
#   z: -0.014670474
# }
# landmark {
#   x: 0.6698419
#   y: 0.5835177
#   z: -0.02841133
# }
# landmark {
#   x: 0.71382445
#   y: 0.8963215
#   z: -0.006906011
# }
# landmark {
#   x: 0.73556906
#   y: 0.5899353
#   z: -0.039042216
# }
# landmark {
#   x: 0.72938013
#   y: 0.54620695
#   z: -0.032439917
# }
# landmark {
#   x: 0.7216741
#   y: 0.50340855
#   z: -0.025922183
# }
# landmark {
#   x: 0.6638819
#   y: 0.67717946
#   z: -0.0038826894
# }
# landmark {
#   x: 0.6273194
#   y: 0.6962615
#   z: 0.012789933
# }
# landmark {
#   x: 0.7236987
#   y: 0.66838384
#   z: -0.002620684
# }
# landmark {
#   x: 0.6441152
#   y: 0.6473268
#   z: -0.0014646732
# }
# landmark {
#   x: 0.7356073
#   y: 0.6970263
#   z: -0.023414887
# }
# landmark {
#   x: 0.73901474
#   y: 0.7567114
#   z: -0.05873184
# }
# landmark {
#   x: 0.6100703
#   y: 0.7099338
#   z: 0.026253987
# }
# landmark {
#   x: 0.63879216
#   y: 0.7091048
#   z: 0.0021229887
# }
# landmark {
#   x: 0.658842
#   y: 0.7159353
#   z: -0.0073650433
# }
# landmark {
#   x: 0.68714017
#   y: 0.71308076
#   z: -0.009877886
# }
# landmark {
#   x: 0.7077097
#   y: 0.70493746
#   z: -0.010312347
# }
# landmark {
#   x: 0.7229872
#   y: 0.6957808
#   z: -0.011895167
# }
# landmark {
#   x: 0.75720614
#   y: 0.6713364
#   z: -0.03617528
# }
# landmark {
#   x: 0.61268413
#   y: 0.75016403
#   z: 0.02440767
# }
# landmark {
#   x: 0.63055277
#   y: 0.64370805
#   z: 0.003129348
# }
# landmark {
#   x: 0.77192855
#   y: 0.7786181
#   z: -0.067699164
# }
# landmark {
#   x: 0.72707003
#   y: 0.7275237
#   z: -0.02428872
# }
# landmark {
#   x: 0.5838717
#   y: 0.6752957
#   z: 0.107401796
# }
# landmark {
#   x: 0.7345972
#   y: 0.6852729
#   z: -0.013033044
# }
# landmark {
#   x: 0.719463
#   y: 0.7659408
#   z: -0.019610683
# }
# landmark {
#   x: 0.65179735
#   y: 0.6610997
#   z: 0.004119707
# }
# landmark {
#   x: 0.73654765
#   y: 0.74529636
#   z: -0.053764813
# }
# landmark {
#   x: 0.5929587
#   y: 0.8097432
#   z: 0.11980825
# }
# landmark {
#   x: 0.7226944
#   y: 0.66208315
#   z: 2.132088e-05
# }
# landmark {
#   x: 0.75073075
#   y: 0.7342514
#   z: -0.066147946
# }
# landmark {
#   x: 0.6450702
#   y: 0.90423226
#   z: 0.042551067
# }
# landmark {
#   x: 0.6433441
#   y: 0.92742074
#   z: 0.06769343
# }
# landmark {
#   x: 0.59399885
#   y: 0.7575667
#   z: 0.07277902
# }
# landmark {
#   x: 0.62445843
#   y: 0.877476
#   z: 0.05595308
# }
# landmark {
#   x: 0.60260636
#   y: 0.6361594
#   z: 0.04678768
# }
# landmark {
#   x: 0.7112393
#   y: 0.97164047
#   z: 0.009099105
# }
# landmark {
#   x: 0.77194595
#   y: 0.782948
#   z: -0.048597228
# }
# landmark {
#   x: 0.71362853
#   y: 0.7420323
#   z: -0.020046318
# }
# landmark {
#   x: 0.61139274
#   y: 0.6740937
#   z: 0.02972116
# }
# landmark {
#   x: 0.6784357
#   y: 0.66847646
#   z: -0.0071845255
# }
# landmark {
#   x: 0.69093686
#   y: 0.6695362
#   z: -0.008846681
# }
# landmark {
#   x: 0.71152776
#   y: 0.87072754
#   z: -0.0074594645
# }
# landmark {
#   x: 0.61474305
#   y: 0.78993636
#   z: 0.031694125
# }
# landmark {
#   x: 0.73822325
#   y: 0.9987392
#   z: 0.017058574
# }
# landmark {
#   x: 0.6900506
#   y: 0.9720974
#   z: 0.0374294
# }
# landmark {
#   x: 0.6684747
#   y: 0.95375395
#   z: 0.050528888
# }
# landmark {
#   x: 0.7682928
#   y: 0.54896855
#   z: -0.029729364
# }
# landmark {
#   x: 0.76915073
#   y: 1.001504
#   z: 0.017811969
# }
# landmark {
#   x: 0.70239943
#   y: 0.66823745
#   z: -0.0075569786
# }
# landmark {
#   x: 0.7128497
#   y: 0.66506475
#   z: -0.004346727
# }
# landmark {
#   x: 0.7193785
#   y: 0.66326845
#   z: -0.0005983217
# }
# landmark {
#   x: 0.6180714
#   y: 0.6397352
#   z: 0.015364515
# }
# landmark {
#   x: 0.7110878
#   y: 0.65611655
#   z: -0.007655455
# }
# landmark {
#   x: 0.69917804
#   y: 0.65520865
#   z: -0.0123461
# }
# landmark {
#   x: 0.6881923
#   y: 0.6552266
#   z: -0.013513801
# }
# landmark {
#   x: 0.67635405
#   y: 0.65679556
#   z: -0.011599171
# }
# landmark {
#   x: 0.6678586
#   y: 0.659025
#   z: -0.00788536
# }
# landmark {
#   x: 0.58858466
#   y: 0.62900126
#   z: 0.083130576
# }
# landmark {
#   x: 0.6696854
#   y: 0.6664142
#   z: -0.004195311
# }
# landmark {
#   x: 0.7752583
#   y: 0.8076839
#   z: -0.03547191
# }
# landmark {
#   x: 0.72365856
#   y: 0.81574494
#   z: -0.02765479
# }
# landmark {
#   x: 0.7390143
#   y: 0.7716508
#   z: -0.043796897
# }
# landmark {
#   x: 0.7545405
#   y: 0.80957305
#   z: -0.03723458
# }
# landmark {
#   x: 0.7695124
#   y: 0.6440916
#   z: -0.030299805
# }
# landmark {
#   x: 0.66689616
#   y: 0.9307124
#   z: 0.03276341
# }
# landmark {
#   x: 0.68808323
#   y: 0.9515757
#   z: 0.02172601
# }
# landmark {
#   x: 0.7390149
#   y: 0.9852318
#   z: -0.00073218223
# }
# landmark {
#   x: 0.6226761
#   y: 0.89821887
#   z: 0.089352064
# }
# landmark {
#   x: 0.7192139
#   y: 0.65918666
#   z: -0.0032306032
# }
# landmark {
#   x: 0.7486079
#   y: 0.7011489
#   z: -0.040795937
# }
# landmark {
#   x: 0.77124417
#   y: 0.988007
#   z: 0.0005386035
# }
# landmark {
#   x: 0.71291876
#   y: 0.987826
#   z: 0.02400876
# }
# landmark {
#   x: 0.598642
#   y: 0.8009183
#   z: 0.07355883
# }
# landmark {
#   x: 0.74328226
#   y: 0.86653167
#   z: -0.020217236
# }
# landmark {
#   x: 0.7411846
#   y: 0.8717808
#   z: -0.0227751
# }
# landmark {
#   x: 0.73894274
#   y: 0.8802937
#   z: -0.02503021
# }
# landmark {
#   x: 0.7367771
#   y: 0.89150715
#   z: -0.02277026
# }
# landmark {
#   x: 0.7306094
#   y: 0.90956104
#   z: -0.011888307
# }
# landmark {
#   x: 0.71808785
#   y: 0.8603836
#   z: -0.011093156
# }
# landmark {
#   x: 0.7141163
#   y: 0.8587385
#   z: -0.011862071
# }
# landmark {
#   x: 0.709932
#   y: 0.8557344
#   z: -0.01272905
# }
# landmark {
#   x: 0.69578695
#   y: 0.8431886
#   z: -0.012127891
# }
# landmark {
#   x: 0.63710517
#   y: 0.79908365
#   z: 0.0073958333
# }
# landmark {
#   x: 0.74657613
#   y: 0.6829528
#   z: -0.028752565
# }
# landmark {
#   x: 0.73562473
#   y: 0.64843976
#   z: -0.0076093893
# }
# landmark {
#   x: 0.7260159
#   y: 0.6523496
#   z: -0.004609077
# }
# landmark {
#   x: 0.7206865
#   y: 0.85806006
#   z: -0.009390821
# }
# landmark {
#   x: 0.63343275
#   y: 0.8477404
#   z: 0.02981788
# }
# landmark {
#   x: 0.75008607
#   y: 0.6469953
#   z: -0.023712182
# }
# landmark {
#   x: 0.721835
#   y: 0.9296893
#   z: -0.0045222663
# }
# landmark {
#   x: 0.7759936
#   y: 0.70507514
#   z: -0.06278553
# }
# landmark {
#   x: 0.7600991
#   y: 0.6907744
#   z: -0.049224913
# }
# landmark {
#   x: 0.77380097
#   y: 0.68658423
#   z: -0.050546285
# }
# landmark {
#   x: 0.7385356
#   y: 0.7304289
#   z: -0.041125048
# }
# landmark {
#   x: 0.7722027
#   y: 0.96772003
#   z: -0.008323904
# }
# landmark {
#   x: 0.7722379
#   y: 0.9424368
#   z: -0.009600354
# }
# landmark {
#   x: 0.7466847
#   y: 0.9410409
#   z: -0.009699153
# }
# landmark {
#   x: 0.6860691
#   y: 0.89106494
#   z: 0.004678658
# }
# landmark {
#   x: 0.70714253
#   y: 0.7824844
#   z: -0.017023342
# }
# landmark {
#   x: 0.70219415
#   y: 0.9132478
#   z: 0.0010804718
# }
# landmark {
#   x: 0.672403
#   y: 0.78073335
#   z: -0.015118295
# }
# landmark {
#   x: 0.6927995
#   y: 0.80259734
#   z: -0.015190465
# }
# landmark {
#   x: 0.6585977
#   y: 0.8130093
#   z: -0.004690326
# }
# landmark {
#   x: 0.74169296
#   y: 0.9652937
#   z: -0.00869279
# }
# landmark {
#   x: 0.72830105
#   y: 0.7413891
#   z: -0.031942178
# }
# landmark {
#   x: 0.6728996
#   y: 0.9074851
#   z: 0.016859103
# }
# landmark {
#   x: 0.6933144
#   y: 0.93067205
#   z: 0.011063544
# }
# landmark {
#   x: 0.6740556
#   y: 0.865349
#   z: 0.0030819618
# }
# landmark {
#   x: 0.61809236
#   y: 0.8240033
#   z: 0.039073657
# }
# landmark {
#   x: 0.654377
#   y: 0.8694002
#   z: 0.015171985
# }
# landmark {
#   x: 0.60694325
#   y: 0.8409288
#   z: 0.07029675
# }
# landmark {
#   x: 0.679888
#   y: 0.82854986
#   z: -0.009650763
# }
# landmark {
#   x: 0.7379658
#   y: 0.7139846
#   z: -0.031963296
# }
# landmark {
#   x: 0.74453324
#   y: 0.76450056
#   z: -0.061142225
# }
# landmark {
#   x: 0.73281217
#   y: 0.770506
#   z: -0.046619266
# }
# landmark {
#   x: 0.75224316
#   y: 0.75213057
#   z: -0.07013575
# }
# landmark {
#   x: 0.7250266
#   y: 0.6330635
#   z: -0.014231229
# }
# landmark {
#   x: 0.7028101
#   y: 0.6235216
#   z: -0.020209443
# }
# landmark {
#   x: 0.68316346
#   y: 0.62153816
#   z: -0.022499721
# }
# landmark {
#   x: 0.6656601
#   y: 0.62445235
#   z: -0.019243648
# }
# landmark {
#   x: 0.65218693
#   y: 0.6325748
#   z: -0.012020204
# }
# landmark {
#   x: 0.640353
#   y: 0.66523737
#   z: 0.008744204
# }
# landmark {
#   x: 0.59163517
#   y: 0.71591043
#   z: 0.06738901
# }
# landmark {
#   x: 0.6525502
#   y: 0.69082415
#   z: 0.0007494697
# }
# landmark {
#   x: 0.6683239
#   y: 0.6959719
#   z: -0.004856977
# }
# landmark {
#   x: 0.6880506
#   y: 0.69576806
#   z: -0.00771444
# }
# landmark {
#   x: 0.70622295
#   y: 0.69104
#   z: -0.0078091854
# }
# landmark {
#   x: 0.7202499
#   y: 0.6842558
#   z: -0.006184021
# }
# landmark {
#   x: 0.7298217
#   y: 0.67767715
#   z: -0.0060954383
# }
# landmark {
#   x: 0.5849544
#   y: 0.71898705
#   z: 0.119674854
# }
# landmark {
#   x: 0.7323742
#   y: 0.77618974
#   z: -0.039367806
# }
# landmark {
#   x: 0.75074756
#   y: 0.7172702
#   z: -0.051530335
# }
# landmark {
#   x: 0.7568457
#   y: 0.7654118
#   z: -0.06998758
# }
# landmark {
#   x: 0.7640334
#   y: 0.77539474
#   z: -0.06277023
# }
# landmark {
#   x: 0.7558438
#   y: 0.76860225
#   z: -0.06323455
# }
# landmark {
#   x: 0.73608196
#   y: 0.78277934
#   z: -0.03338934
# }
# landmark {
#   x: 0.76719373
#   y: 0.7771367
#   z: -0.06610748
# }
# landmark {
#   x: 0.7671525
#   y: 0.7816928
#   z: -0.049332563
# }
# landmark {
#   x: 0.72845596
#   y: 0.66257715
#   z: -0.00068091485
# }
# landmark {
#   x: 0.7375003
#   y: 0.66715467
#   z: -0.007308582
# }
# landmark {
#   x: 0.7432791
#   y: 0.67038697
#   z: -0.016025607
# }
# landmark {
#   x: 0.6622245
#   y: 0.66042435
#   z: -0.0037135135
# }
# landmark {
#   x: 0.653695
#   y: 0.6501811
#   z: -0.0038340164
# }
# landmark {
#   x: 0.7873455
#   y: 0.70858914
#   z: -0.055537175
# }
# landmark {
#   x: 0.8580713
#   y: 0.6702608
#   z: 0.032088745
# }
# landmark {
#   x: 0.7888038
#   y: 0.7785042
#   z: -0.04639036
# }
# landmark {
#   x: 0.89621556
#   y: 0.6009387
#   z: 0.10434845
# }
# landmark {
#   x: 0.8208475
#   y: 0.68278414
#   z: 0.012887795
# }
# landmark {
#   x: 0.8340634
#   y: 0.684947
#   z: 0.016259462
# }
# landmark {
#   x: 0.84655845
#   y: 0.6845888
#   z: 0.02206035
# }
# landmark {
#   x: 0.8627443
#   y: 0.6768175
#   z: 0.035658747
# }
# landmark {
#   x: 0.8098849
#   y: 0.67712873
#   z: 0.011780032
# }
# landmark {
#   x: 0.8390113
#   y: 0.6424297
#   z: 0.007686198
# }
# landmark {
#   x: 0.8256107
#   y: 0.6423819
#   z: 0.005460267
# }
# landmark {
#   x: 0.8514471
#   y: 0.64512527
#   z: 0.014728453
# }
# landmark {
#   x: 0.85935116
#   y: 0.65110534
#   z: 0.022164144
# }
# landmark {
#   x: 0.87310016
#   y: 0.6878046
#   z: 0.04426253
# }
# landmark {
#   x: 0.8209893
#   y: 0.9475422
#   z: 0.016317185
# }
# landmark {
#   x: 0.86218005
#   y: 0.66766137
#   z: 0.037215393
# }
# landmark {
#   x: 0.90233004
#   y: 0.6812508
#   z: 0.113277204
# }
# landmark {
#   x: 0.8858553
#   y: 0.67588574
#   z: 0.060222022
# }
# landmark {
#   x: 0.836854
#   y: 0.7583871
#   z: 0.003105406
# }
# landmark {
#   x: 0.79260707
#   y: 0.83753663
#   z: -0.03348252
# }
# landmark {
#   x: 0.7890031
#   y: 0.8580504
#   z: -0.025916386
# }
# landmark {
#   x: 0.80904245
#   y: 0.84205735
#   z: -0.021003935
# }
# landmark {
#   x: 0.8188529
#   y: 0.8488966
#   z: -0.007093393
# }
# landmark {
#   x: 0.8008082
#   y: 0.85783327
#   z: -0.016998917
# }
# landmark {
#   x: 0.80970275
#   y: 0.8587857
#   z: -0.004638846
# }
# landmark {
#   x: 0.83230084
#   y: 0.87967
#   z: 0.019039206
# }
# landmark {
#   x: 0.7913062
#   y: 0.7685989
#   z: -0.071965665
# }
# landmark {
#   x: 0.79303294
#   y: 0.7503988
#   z: -0.076535836
# }
# landmark {
#   x: 0.88080114
#   y: 0.6283628
#   z: 0.028653536
# }
# landmark {
#   x: 0.8088854
#   y: 0.71106744
#   z: -0.0045707985
# }
# landmark {
#   x: 0.8176447
#   y: 0.7651625
#   z: -0.03209379
# }
# landmark {
#   x: 0.81764954
#   y: 0.7556671
#   z: -0.027690686
# }
# landmark {
#   x: 0.8734666
#   y: 0.7576345
#   z: 0.028185051
# }
# landmark {
#   x: 0.7906337
#   y: 0.72737855
#   z: -0.068517454
# }
# landmark {
#   x: 0.85345185
#   y: 0.6076646
#   z: -0.0022599779
# }
# landmark {
#   x: 0.8699661
#   y: 0.6148269
#   z: 0.012248271
# }
# landmark {
#   x: 0.88717914
#   y: 0.56654227
#   z: 0.07278002
# }
# landmark {
#   x: 0.7973248
#   y: 0.6191079
#   z: -0.023562087
# }
# landmark {
#   x: 0.8133103
#   y: 0.6460899
#   z: 0.007793064
# }
# landmark {
#   x: 0.84206736
#   y: 0.859888
#   z: 0.023513258
# }
# landmark {
#   x: 0.8836305
#   y: 0.8567359
#   z: 0.15643165
# }
# landmark {
#   x: 0.8073307
#   y: 0.77541065
#   z: -0.028522832
# }
# landmark {
#   x: 0.79631174
#   y: 0.7821239
#   z: -0.03216804
# }
# landmark {
#   x: 0.8290119
#   y: 0.860297
#   z: 0.020773442
# }
# landmark {
#   x: 0.8222538
#   y: 0.8595917
#   z: 0.015580855
# }
# landmark {
#   x: 0.87675154
#   y: 0.6017849
#   z: 0.019755613
# }
# landmark {
#   x: 0.8168684
#   y: 0.77379215
#   z: -0.024258925
# }
# landmark {
#   x: 0.8300038
#   y: 0.60745895
#   z: -0.014674488
# }
# landmark {
#   x: 0.8330409
#   y: 0.5911393
#   z: -0.017616814
# }
# landmark {
#   x: 0.8417158
#   y: 0.51803726
#   z: 0.007939874
# }
# landmark {
#   x: 0.8822962
#   y: 0.5830707
#   z: 0.042765606
# }
# landmark {
#   x: 0.8365638
#   y: 0.5528834
#   z: -0.005273489
# }
# landmark {
#   x: 0.8875555
#   y: 0.6199478
#   z: 0.041497704
# }
# landmark {
#   x: 0.8924086
#   y: 0.6111893
#   z: 0.070926726
# }
# landmark {
#   x: 0.7913408
#   y: 0.8495777
#   z: -0.031144254
# }
# landmark {
#   x: 0.8047999
#   y: 0.8516977
#   z: -0.019573962
# }
# landmark {
#   x: 0.81449974
#   y: 0.85409194
#   z: -0.0070114494
# }
# landmark {
#   x: 0.80359566
#   y: 0.77928364
#   z: -0.026283544
# }
# landmark {
#   x: 0.8257668
#   y: 0.86014146
#   z: 0.017821372
# }
# landmark {
#   x: 0.8209036
#   y: 0.8655491
#   z: 0.008027541
# }
# landmark {
#   x: 0.8201208
#   y: 0.85875297
#   z: 0.014847194
# }
# landmark {
#   x: 0.8023338
#   y: 0.7679635
#   z: -0.048507567
# }
# landmark {
#   x: 0.8059399
#   y: 0.8575611
#   z: -0.002667625
# }
# landmark {
#   x: 0.7969162
#   y: 0.8589161
#   z: -0.011683527
# }
# landmark {
#   x: 0.7859575
#   y: 0.8604566
#   z: -0.019637104
# }
# landmark {
#   x: 0.7910483
#   y: 0.9185756
#   z: -0.006808041
# }
# landmark {
#   x: 0.79199934
#   y: 0.89885086
#   z: -0.02042317
# }
# landmark {
#   x: 0.79147893
#   y: 0.8864342
#   z: -0.02244194
# }
# landmark {
#   x: 0.7900199
#   y: 0.8752589
#   z: -0.019457912
# }
# landmark {
#   x: 0.7882328
#   y: 0.86792034
#   z: -0.017523928
# }
# landmark {
#   x: 0.8088597
#   y: 0.8637345
#   z: -0.001057019
# }
# landmark {
#   x: 0.8113145
#   y: 0.86624277
#   z: -0.0031903894
# }
# landmark {
#   x: 0.8147073
#   y: 0.8718261
#   z: -0.0046853935
# }
# landmark {
#   x: 0.81740683
#   y: 0.8787675
#   z: -0.0012689923
# }
# landmark {
#   x: 0.8291749
#   y: 0.82637084
#   z: -0.0019095298
# }
# landmark {
#   x: 0.89545095
#   y: 0.7652394
#   z: 0.1759097
# }
# landmark {
#   x: 0.8140212
#   y: 0.8623477
#   z: 0.008502017
# }
# landmark {
#   x: 0.8173835
#   y: 0.86322594
#   z: 0.0073474827
# }
# landmark {
#   x: 0.7922207
#   y: 0.7912688
#   z: -0.032630507
# }
# landmark {
#   x: 0.81135637
#   y: 0.7860638
#   z: -0.015076637
# }
# landmark {
#   x: 0.7941725
#   y: 0.786935
#   z: -0.03287037
# }
# landmark {
#   x: 0.8225633
#   y: 0.72223395
#   z: 0.00332995
# }
# landmark {
#   x: 0.84408987
#   y: 0.7352976
#   z: 0.0113293715
# }
# landmark {
#   x: 0.81876445
#   y: 0.7643314
#   z: -0.019220464
# }
# landmark {
#   x: 0.87030435
#   y: 0.53823274
#   z: 0.038791142
# }
# landmark {
#   x: 0.86484176
#   y: 0.5627842
#   z: 0.017763961
# }
# landmark {
#   x: 0.85831434
#   y: 0.5916176
#   z: 0.00066444825
# }
# landmark {
#   x: 0.82179826
#   y: 0.89421356
#   z: 0.01029659
# }
# landmark {
#   x: 0.80236876
#   y: 0.59356207
#   z: -0.029401056
# }
# landmark {
#   x: 0.80546236
#   y: 0.54985726
#   z: -0.020884007
# }
# landmark {
#   x: 0.808291
#   y: 0.5075693
#   z: -0.013040125
# }
# landmark {
#   x: 0.8570643
#   y: 0.6821614
#   z: 0.029623318
# }
# landmark {
#   x: 0.88647324
#   y: 0.70068896
#   z: 0.054789264
# }
# landmark {
#   x: 0.80317223
#   y: 0.67165035
#   z: 0.012421913
# }
# landmark {
#   x: 0.873599
#   y: 0.65415615
#   z: 0.037026558
# }
# landmark {
#   x: 0.7998581
#   y: 0.69854814
#   z: -0.0118698655
# }
# landmark {
#   x: 0.81097955
#   y: 0.7575348
#   z: -0.047530863
# }
# landmark {
#   x: 0.8979761
#   y: 0.71399033
#   z: 0.073897965
# }
# landmark {
#   x: 0.8794253
#   y: 0.7128724
#   z: 0.041890956
# }
# landmark {
#   x: 0.86451083
#   y: 0.71889585
#   z: 0.026509305
# }
# landmark {
#   x: 0.8401022
#   y: 0.7154975
#   z: 0.016112693
# }
# landmark {
#   x: 0.82129544
#   y: 0.7072348
#   z: 0.00957504
# }
# landmark {
#   x: 0.8074612
#   y: 0.69794893
#   z: 0.00304817
# }
# landmark {
#   x: 0.7840095
#   y: 0.67212766
#   z: -0.031411383
# }
# landmark {
#   x: 0.89756477
#   y: 0.7525655
#   z: 0.07185625
# }
# landmark {
#   x: 0.88384
#   y: 0.65051246
#   z: 0.045480687
# }
# landmark {
#   x: 0.7854808
#   y: 0.7786152
#   z: -0.06522604
# }
# landmark {
#   x: 0.809823
#   y: 0.7286564
#   z: -0.010034967
# }
# landmark {
#   x: 0.8996185
#   y: 0.6815843
#   z: 0.16174537
# }
# landmark {
#   x: 0.797544
#   y: 0.68718225
#   z: -0.0013895569
# }
# landmark {
#   x: 0.81834495
#   y: 0.7659998
#   z: -0.004712323
# }
# landmark {
#   x: 0.8663525
#   y: 0.6676
#   z: 0.04071405
# }
# landmark {
#   x: 0.81049645
#   y: 0.74604386
#   z: -0.04243816
# }
# landmark {
#   x: 0.8915545
#   y: 0.8099339
#   z: 0.17028482
# }
# landmark {
#   x: 0.80298054
#   y: 0.66544217
#   z: 0.015683116
# }
# landmark {
#   x: 0.8009314
#   y: 0.7347625
#   z: -0.058011044
# }
# landmark {
#   x: 0.8673417
#   y: 0.89969546
#   z: 0.077595375
# }
# landmark {
#   x: 0.8617957
#   y: 0.92177606
#   z: 0.10338318
# }
# landmark {
#   x: 0.9027259
#   y: 0.7598566
#   z: 0.12440856
# }
# landmark {
#   x: 0.88081425
#   y: 0.87432545
#   z: 0.097242214
# }
# landmark {
#   x: 0.89737093
#   y: 0.6435314
#   z: 0.09620372
# }
# landmark {
#   x: 0.8224647
#   y: 0.9673002
#   z: 0.025903918
# }
# landmark {
#   x: 0.7827156
#   y: 0.7830138
#   z: -0.047132768
# }
# landmark {
#   x: 0.82096976
#   y: 0.74295586
#   z: -0.0027431725
# }
# landmark {
#   x: 0.89500725
#   y: 0.67965263
#   z: 0.07656399
# }
# landmark {
#   x: 0.8454865
#   y: 0.67358804
#   z: 0.022167377
# }
# landmark {
#   x: 0.83394164
#   y: 0.6744506
#   z: 0.017153602
# }
# landmark {
#   x: 0.82414365
#   y: 0.86907387
#   z: 0.011083239
# }
# landmark {
#   x: 0.89483505
#   y: 0.7903983
#   z: 0.077459164
# }
# landmark {
#   x: 0.7975951
#   y: 0.99598324
#   z: 0.026536863
# }
# landmark {
#   x: 0.832528
#   y: 0.96619076
#   z: 0.060773354
# }
# landmark {
#   x: 0.8460709
#   y: 0.94733477
#   z: 0.07970496
# }
# landmark {
#   x: 0.8228739
#   y: 0.67281437
#   z: 0.0143775055
# }
# landmark {
#   x: 0.81256276
#   y: 0.6690697
#   z: 0.014383031
# }
# landmark {
#   x: 0.80623806
#   y: 0.6668879
#   z: 0.016177636
# }
# landmark {
#   x: 0.89140844
#   y: 0.64669144
#   z: 0.060842063
# }
# landmark {
#   x: 0.8136245
#   y: 0.6603414
#   z: 0.011485906
# }
# landmark {
#   x: 0.8247662
#   y: 0.6604053
#   z: 0.010020718
# }
# landmark {
#   x: 0.8356857
#   y: 0.66099566
#   z: 0.01274092
# }
# landmark {
#   x: 0.84669375
#   y: 0.6631938
#   z: 0.018258603
# }
# landmark {
#   x: 0.85416996
#   y: 0.66558
#   z: 0.02411196
# }
# landmark {
#   x: 0.8999745
#   y: 0.6369423
#   z: 0.13625641
# }
# landmark {
#   x: 0.85291207
#   y: 0.6719215
#   z: 0.027559785
# }
# landmark {
#   x: 0.8178704
#   y: 0.81454366
#   z: -0.012934203
# }
# landmark {
#   x: 0.8082665
#   y: 0.772038
#   z: -0.033968363
# }
# landmark {
#   x: 0.7937142
#   y: 0.8090464
#   z: -0.030987114
# }
# landmark {
#   x: 0.8523657
#   y: 0.9253112
#   z: 0.061246585
# }
# landmark {
#   x: 0.837731
#   y: 0.94606596
#   z: 0.044488665
# }
# landmark {
#   x: 0.80073404
#   y: 0.9827848
#   z: 0.008473683
# }
# landmark {
#   x: 0.8735008
#   y: 0.8942608
#   z: 0.13169214
# }
# landmark {
#   x: 0.8063979
#   y: 0.66257524
#   z: 0.013921608
# }
# landmark {
#   x: 0.7943698
#   y: 0.70203114
#   z: -0.03302029
# }
# landmark {
#   x: 0.81751597
#   y: 0.98305947
#   z: 0.04118481
# }
# landmark {
#   x: 0.89842546
#   y: 0.8011268
#   z: 0.123089895
# }
# landmark {
#   x: 0.7998925
#   y: 0.8656445
#   z: -0.009661477
# }
# landmark {
#   x: 0.80251557
#   y: 0.87087905
#   z: -0.011862608
# }
# landmark {
#   x: 0.80500305
#   y: 0.87946373
#   z: -0.013499573
# }
# landmark {
#   x: 0.8067363
#   y: 0.8905206
#   z: -0.01081521
# }
# landmark {
#   x: 0.80869126
#   y: 0.9079507
#   z: 0.00087990676
# }
# landmark {
#   x: 0.8172882
#   y: 0.8588984
#   z: 0.0065138275
# }
# landmark {
#   x: 0.8218503
#   y: 0.8569442
#   z: 0.007261019
# }
# landmark {
#   x: 0.8259693
#   y: 0.8539661
#   z: 0.007483441
# }
# landmark {
#   x: 0.83837134
#   y: 0.8415116
#   z: 0.01137549
# }
# landmark {
#   x: 0.88175714
#   y: 0.7993073
#   z: 0.046122167
# }
# landmark {
#   x: 0.7916129
#   y: 0.6842317
#   z: -0.020831166
# }
# landmark {
#   x: 0.7944604
#   y: 0.65103817
#   z: 0.0025952412
# }
# landmark {
#   x: 0.8012583
#   y: 0.6555608
#   z: 0.010051093
# }
# landmark {
#   x: 0.81320494
#   y: 0.8566044
#   z: 0.0074945246
# }
# landmark {
#   x: 0.87996703
#   y: 0.84596187
#   z: 0.0687903
# }
# landmark {
#   x: 0.7855722
#   y: 0.64861345
#   z: -0.01759448
# }
# landmark {
#   x: 0.8147583
#   y: 0.9270194
#   z: 0.009231851
# }
# landmark {
#   x: 0.78603673
#   y: 0.6913549
#   z: -0.04509259
# }
# landmark {
#   x: 0.804559
#   y: 0.73119235
#   z: -0.030751199
# }
# landmark {
#   x: 0.7951822
#   y: 0.9395559
#   z: -0.003173181
# }
# landmark {
#   x: 0.8425997
#   y: 0.8881552
#   z: 0.02874679
# }
# landmark {
#   x: 0.8286063
#   y: 0.78230155
#   z: 0.0013848231
# }
# landmark {
#   x: 0.8297572
#   y: 0.91015947
#   z: 0.019992243
# }
# landmark {
#   x: 0.85740983
#   y: 0.78131247
#   z: 0.012929223
# }
# landmark {
#   x: 0.8406922
#   y: 0.8023289
#   z: 0.007491976
# }
# landmark {
#   x: 0.8670072
#   y: 0.8125721
#   z: 0.027215159
# }
# landmark {
#   x: 0.799927
#   y: 0.96334606
#   z: -0.00019475385
# }
# landmark {
#   x: 0.8114144
#   y: 0.7421799
#   z: -0.018779896
# }
# landmark {
#   x: 0.85124105
#   y: 0.90339595
#   z: 0.043886196
# }
# landmark {
#   x: 0.83606523
#   y: 0.926498
#   z: 0.031968452
# }
# landmark {
#   x: 0.8531636
#   y: 0.8630758
#   z: 0.03173535
# }
# landmark {
#   x: 0.8902635
#   y: 0.8231293
#   z: 0.08285254
# }
# landmark {
#   x: 0.86619556
#   y: 0.86648655
#   z: 0.047956843
# }
# landmark {
#   x: 0.89196813
#   y: 0.83952606
#   z: 0.11752421
# }
# landmark {
#   x: 0.85034966
#   y: 0.82758194
#   z: 0.017000813
# }
# landmark {
#   x: 0.80176526
#   y: 0.7151207
#   z: -0.020743366
# }
# landmark {
#   x: 0.80689603
#   y: 0.76511145
#   z: -0.05091416
# }
# landmark {
#   x: 0.81381243
#   y: 0.7709952
#   z: -0.03471741
# }
# landmark {
#   x: 0.8029073
#   y: 0.7527721
#   z: -0.062422436
# }
# landmark {
#   x: 0.8055708
#   y: 0.63646543
#   z: -0.00030839178
# }
# landmark {
#   x: 0.82711
#   y: 0.62892056
#   z: -3.3899938e-05
# }
# landmark {
#   x: 0.84497285
#   y: 0.62850976
#   z: 0.003931842
# }
# landmark {
#   x: 0.85961044
#   y: 0.63201106
#   z: 0.0128565375
# }
# landmark {
#   x: 0.86924666
#   y: 0.640149
#   z: 0.024003891
# }
# landmark {
#   x: 0.8749795
#   y: 0.6712137
#   z: 0.047548246
# }
# landmark {
#   x: 0.9041996
#   y: 0.72009206
#   z: 0.120226905
# }
# landmark {
#   x: 0.86688393
#   y: 0.69522625
#   z: 0.036682267
# }
# landmark {
#   x: 0.8544519
#   y: 0.69953865
#   z: 0.026315087
# }
# landmark {
#   x: 0.83734626
#   y: 0.69906074
#   z: 0.018069357
# }
# landmark {
#   x: 0.820529
#   y: 0.6941404
#   z: 0.012579803
# }
# landmark {
#   x: 0.8075277
#   y: 0.6869919
#   z: 0.009294293
# }
# landmark {
#   x: 0.7990353
#   y: 0.6801352
#   z: 0.0065404125
# }
# landmark {
#   x: 0.8969692
#   y: 0.7232448
#   z: 0.17390491
# }
# landmark {
#   x: 0.81238085
#   y: 0.7763066
#   z: -0.027729169
# }
# landmark {
#   x: 0.7966642
#   y: 0.71798676
#   z: -0.04354373
# }
# landmark {
#   x: 0.7993146
#   y: 0.7656678
#   z: -0.06370455
# }
# landmark {
#   x: 0.7905403
#   y: 0.77537954
#   z: -0.05907958
# }
# landmark {
#   x: 0.7979404
#   y: 0.76875263
#   z: -0.056682464
# }
# landmark {
#   x: 0.80800307
#   y: 0.78258914
#   z: -0.023690967
# }
# landmark {
#   x: 0.7890569
#   y: 0.7771418
#   z: -0.063028194
# }
# landmark {
#   x: 0.78640246
#   y: 0.7815919
#   z: -0.046696585
# }
# landmark {
#   x: 0.7987769
#   y: 0.6656689
#   z: 0.012323157
# }
# landmark {
#   x: 0.7924146
#   y: 0.66950744
#   z: 0.002722306
# }
# landmark {
#   x: 0.79015625
#   y: 0.67211694
#   z: -0.007805544
# }
# landmark {
#   x: 0.85874265
#   y: 0.6669563
#   z: 0.029830983
# }
# landmark {
#   x: 0.86590385
#   y: 0.65721786
#   z: 0.031634327
# }

# %%
results.face_landmarks.landmark[0]
# Out:
# x: 0.7755465
# y: 0.8414613
# z: -0.03850935

# %% [markdown]
# # Capture Landmarks & Export to CSV

# %%
import csv
import os
import numpy as np

# %%
num_coords = len(results.pose_landmarks.landmark)+len(results.face_landmarks.landmark)
num_coords
# Out:
# 501

# %%
landmarks = ["class"]
for value in range(1, num_coords+1):
    landmarks += ["x{}".format(value), "y{}".format(value), 'z{}'.format(value), 'v{}'.format(value)]

# %%
landmarks
# Out:
# ['class',
#  'x1',
#  'y1',
#  'z1',
#  'v1',
#  'x2',
#  'y2',
#  'z2',
#  'v2',
#  'x3',
#  'y3',
#  'z3',
#  'v3',
#  'x4',
#  'y4',
#  'z4',
#  'v4',
#  'x5',
#  'y5',
#  'z5',
#  'v5',
#  'x6',
#  'y6',
#  'z6',
#  'v6',
#  'x7',
#  'y7',
#  'z7',
#  'v7',
#  'x8',
#  'y8',
#  'z8',
#  'v8',
#  'x9',
#  'y9',
#  'z9',
#  'v9',
#  'x10',
#  'y10',
#  'z10',
#  'v10',
#  'x11',
#  'y11',
#  'z11',
#  'v11',
#  'x12',
#  'y12',
#  'z12',
#  'v12',
#  'x13',
#  'y13',
#  'z13',
#  'v13',
#  'x14',
#  'y14',
#  'z14',
#  'v14',
#  'x15',
#  'y15',
#  'z15',
#  'v15',
#  'x16',
#  'y16',
#  'z16',
#  'v16',
#  'x17',
#  'y17',
#  'z17',
#  'v17',
#  'x18',
#  'y18',
#  'z18',
#  'v18',
#  'x19',
#  'y19',
#  'z19',
#  'v19',
#  'x20',
#  'y20',
#  'z20',
#  'v20',
#  'x21',
#  'y21',
#  'z21',
#  'v21',
#  'x22',
#  'y22',
#  'z22',
#  'v22',
#  'x23',
#  'y23',
#  'z23',
#  'v23',
#  'x24',
#  'y24',
#  'z24',
#  'v24',
#  'x25',
#  'y25',
#  'z25',
#  'v25',
#  'x26',
#  'y26',
#  'z26',
#  'v26',
#  'x27',
#  'y27',
#  'z27',
#  'v27',
#  'x28',
#  'y28',
#  'z28',
#  'v28',
#  'x29',
#  'y29',
#  'z29',
#  'v29',
#  'x30',
#  'y30',
#  'z30',
#  'v30',
#  'x31',
#  'y31',
#  'z31',
#  'v31',
#  'x32',
#  'y32',
#  'z32',
#  'v32',
#  'x33',
#  'y33',
#  'z33',
#  'v33',
#  'x34',
#  'y34',
#  'z34',
#  'v34',
#  'x35',
#  'y35',
#  'z35',
#  'v35',
#  'x36',
#  'y36',
#  'z36',
#  'v36',
#  'x37',
#  'y37',
#  'z37',
#  'v37',
#  'x38',
#  'y38',
#  'z38',
#  'v38',
#  'x39',
#  'y39',
#  'z39',
#  'v39',
#  'x40',
#  'y40',
#  'z40',
#  'v40',
#  'x41',
#  'y41',
#  'z41',
#  'v41',
#  'x42',
#  'y42',
#  'z42',
#  'v42',
#  'x43',
#  'y43',
#  'z43',
#  'v43',
#  'x44',
#  'y44',
#  'z44',
#  'v44',
#  'x45',
#  'y45',
#  'z45',
#  'v45',
#  'x46',
#  'y46',
#  'z46',
#  'v46',
#  'x47',
#  'y47',
#  'z47',
#  'v47',
#  'x48',
#  'y48',
#  'z48',
#  'v48',
#  'x49',
#  'y49',
#  'z49',
#  'v49',
#  'x50',
#  'y50',
#  'z50',
#  'v50',
#  'x51',
#  'y51',
#  'z51',
#  'v51',
#  'x52',
#  'y52',
#  'z52',
#  'v52',
#  'x53',
#  'y53',
#  'z53',
#  'v53',
#  'x54',
#  'y54',
#  'z54',
#  'v54',
#  'x55',
#  'y55',
#  'z55',
#  'v55',
#  'x56',
#  'y56',
#  'z56',
#  'v56',
#  'x57',
#  'y57',
#  'z57',
#  'v57',
#  'x58',
#  'y58',
#  'z58',
#  'v58',
#  'x59',
#  'y59',
#  'z59',
#  'v59',
#  'x60',
#  'y60',
#  'z60',
#  'v60',
#  'x61',
#  'y61',
#  'z61',
#  'v61',
#  'x62',
#  'y62',
#  'z62',
#  'v62',
#  'x63',
#  'y63',
#  'z63',
#  'v63',
#  'x64',
#  'y64',
#  'z64',
#  'v64',
#  'x65',
#  'y65',
#  'z65',
#  'v65',
#  'x66',
#  'y66',
#  'z66',
#  'v66',
#  'x67',
#  'y67',
#  'z67',
#  'v67',
#  'x68',
#  'y68',
#  'z68',
#  'v68',
#  'x69',
#  'y69',
#  'z69',
#  'v69',
#  'x70',
#  'y70',
#  'z70',
#  'v70',
#  'x71',
#  'y71',
#  'z71',
#  'v71',
#  'x72',
#  'y72',
#  'z72',
#  'v72',
#  'x73',
#  'y73',
#  'z73',
#  'v73',
#  'x74',
#  'y74',
#  'z74',
#  'v74',
#  'x75',
#  'y75',
#  'z75',
#  'v75',
#  'x76',
#  'y76',
#  'z76',
#  'v76',
#  'x77',
#  'y77',
#  'z77',
#  'v77',
#  'x78',
#  'y78',
#  'z78',
#  'v78',
#  'x79',
#  'y79',
#  'z79',
#  'v79',
#  'x80',
#  'y80',
#  'z80',
#  'v80',
#  'x81',
#  'y81',
#  'z81',
#  'v81',
#  'x82',
#  'y82',
#  'z82',
#  'v82',
#  'x83',
#  'y83',
#  'z83',
#  'v83',
#  'x84',
#  'y84',
#  'z84',
#  'v84',
#  'x85',
#  'y85',
#  'z85',
#  'v85',
#  'x86',
#  'y86',
#  'z86',
#  'v86',
#  'x87',
#  'y87',
#  'z87',
#  'v87',
#  'x88',
#  'y88',
#  'z88',
#  'v88',
#  'x89',
#  'y89',
#  'z89',
#  'v89',
#  'x90',
#  'y90',
#  'z90',
#  'v90',
#  'x91',
#  'y91',
#  'z91',
#  'v91',
#  'x92',
#  'y92',
#  'z92',
#  'v92',
#  'x93',
#  'y93',
#  'z93',
#  'v93',
#  'x94',
#  'y94',
#  'z94',
#  'v94',
#  'x95',
#  'y95',
#  'z95',
#  'v95',
#  'x96',
#  'y96',
#  'z96',
#  'v96',
#  'x97',
#  'y97',
#  'z97',
#  'v97',
#  'x98',
#  'y98',
#  'z98',
#  'v98',
#  'x99',
#  'y99',
#  'z99',
#  'v99',
#  'x100',
#  'y100',
#  'z100',
#  'v100',
#  'x101',
#  'y101',
#  'z101',
#  'v101',
#  'x102',
#  'y102',
#  'z102',
#  'v102',
#  'x103',
#  'y103',
#  'z103',
#  'v103',
#  'x104',
#  'y104',
#  'z104',
#  'v104',
#  'x105',
#  'y105',
#  'z105',
#  'v105',
#  'x106',
#  'y106',
#  'z106',
#  'v106',
#  'x107',
#  'y107',
#  'z107',
#  'v107',
#  'x108',
#  'y108',
#  'z108',
#  'v108',
#  'x109',
#  'y109',
#  'z109',
#  'v109',
#  'x110',
#  'y110',
#  'z110',
#  'v110',
#  'x111',
#  'y111',
#  'z111',
#  'v111',
#  'x112',
#  'y112',
#  'z112',
#  'v112',
#  'x113',
#  'y113',
#  'z113',
#  'v113',
#  'x114',
#  'y114',
#  'z114',
#  'v114',
#  'x115',
#  'y115',
#  'z115',
#  'v115',
#  'x116',
#  'y116',
#  'z116',
#  'v116',
#  'x117',
#  'y117',
#  'z117',
#  'v117',
#  'x118',
#  'y118',
#  'z118',
#  'v118',
#  'x119',
#  'y119',
#  'z119',
#  'v119',
#  'x120',
#  'y120',
#  'z120',
#  'v120',
#  'x121',
#  'y121',
#  'z121',
#  'v121',
#  'x122',
#  'y122',
#  'z122',
#  'v122',
#  'x123',
#  'y123',
#  'z123',
#  'v123',
#  'x124',
#  'y124',
#  'z124',
#  'v124',
#  'x125',
#  'y125',
#  'z125',
#  'v125',
#  'x126',
#  'y126',
#  'z126',
#  'v126',
#  'x127',
#  'y127',
#  'z127',
#  'v127',
#  'x128',
#  'y128',
#  'z128',
#  'v128',
#  'x129',
#  'y129',
#  'z129',
#  'v129',
#  'x130',
#  'y130',
#  'z130',
#  'v130',
#  'x131',
#  'y131',
#  'z131',
#  'v131',
#  'x132',
#  'y132',
#  'z132',
#  'v132',
#  'x133',
#  'y133',
#  'z133',
#  'v133',
#  'x134',
#  'y134',
#  'z134',
#  'v134',
#  'x135',
#  'y135',
#  'z135',
#  'v135',
#  'x136',
#  'y136',
#  'z136',
#  'v136',
#  'x137',
#  'y137',
#  'z137',
#  'v137',
#  'x138',
#  'y138',
#  'z138',
#  'v138',
#  'x139',
#  'y139',
#  'z139',
#  'v139',
#  'x140',
#  'y140',
#  'z140',
#  'v140',
#  'x141',
#  'y141',
#  'z141',
#  'v141',
#  'x142',
#  'y142',
#  'z142',
#  'v142',
#  'x143',
#  'y143',
#  'z143',
#  'v143',
#  'x144',
#  'y144',
#  'z144',
#  'v144',
#  'x145',
#  'y145',
#  'z145',
#  'v145',
#  'x146',
#  'y146',
#  'z146',
#  'v146',
#  'x147',
#  'y147',
#  'z147',
#  'v147',
#  'x148',
#  'y148',
#  'z148',
#  'v148',
#  'x149',
#  'y149',
#  'z149',
#  'v149',
#  'x150',
#  'y150',
#  'z150',
#  'v150',
#  'x151',
#  'y151',
#  'z151',
#  'v151',
#  'x152',
#  'y152',
#  'z152',
#  'v152',
#  'x153',
#  'y153',
#  'z153',
#  'v153',
#  'x154',
#  'y154',
#  'z154',
#  'v154',
#  'x155',
#  'y155',
#  'z155',
#  'v155',
#  'x156',
#  'y156',
#  'z156',
#  'v156',
#  'x157',
#  'y157',
#  'z157',
#  'v157',
#  'x158',
#  'y158',
#  'z158',
#  'v158',
#  'x159',
#  'y159',
#  'z159',
#  'v159',
#  'x160',
#  'y160',
#  'z160',
#  'v160',
#  'x161',
#  'y161',
#  'z161',
#  'v161',
#  'x162',
#  'y162',
#  'z162',
#  'v162',
#  'x163',
#  'y163',
#  'z163',
#  'v163',
#  'x164',
#  'y164',
#  'z164',
#  'v164',
#  'x165',
#  'y165',
#  'z165',
#  'v165',
#  'x166',
#  'y166',
#  'z166',
#  'v166',
#  'x167',
#  'y167',
#  'z167',
#  'v167',
#  'x168',
#  'y168',
#  'z168',
#  'v168',
#  'x169',
#  'y169',
#  'z169',
#  'v169',
#  'x170',
#  'y170',
#  'z170',
#  'v170',
#  'x171',
#  'y171',
#  'z171',
#  'v171',
#  'x172',
#  'y172',
#  'z172',
#  'v172',
#  'x173',
#  'y173',
#  'z173',
#  'v173',
#  'x174',
#  'y174',
#  'z174',
#  'v174',
#  'x175',
#  'y175',
#  'z175',
#  'v175',
#  'x176',
#  'y176',
#  'z176',
#  'v176',
#  'x177',
#  'y177',
#  'z177',
#  'v177',
#  'x178',
#  'y178',
#  'z178',
#  'v178',
#  'x179',
#  'y179',
#  'z179',
#  'v179',
#  'x180',
#  'y180',
#  'z180',
#  'v180',
#  'x181',
#  'y181',
#  'z181',
#  'v181',
#  'x182',
#  'y182',
#  'z182',
#  'v182',
#  'x183',
#  'y183',
#  'z183',
#  'v183',
#  'x184',
#  'y184',
#  'z184',
#  'v184',
#  'x185',
#  'y185',
#  'z185',
#  'v185',
#  'x186',
#  'y186',
#  'z186',
#  'v186',
#  'x187',
#  'y187',
#  'z187',
#  'v187',
#  'x188',
#  'y188',
#  'z188',
#  'v188',
#  'x189',
#  'y189',
#  'z189',
#  'v189',
#  'x190',
#  'y190',
#  'z190',
#  'v190',
#  'x191',
#  'y191',
#  'z191',
#  'v191',
#  'x192',
#  'y192',
#  'z192',
#  'v192',
#  'x193',
#  'y193',
#  'z193',
#  'v193',
#  'x194',
#  'y194',
#  'z194',
#  'v194',
#  'x195',
#  'y195',
#  'z195',
#  'v195',
#  'x196',
#  'y196',
#  'z196',
#  'v196',
#  'x197',
#  'y197',
#  'z197',
#  'v197',
#  'x198',
#  'y198',
#  'z198',
#  'v198',
#  'x199',
#  'y199',
#  'z199',
#  'v199',
#  'x200',
#  'y200',
#  'z200',
#  'v200',
#  'x201',
#  'y201',
#  'z201',
#  'v201',
#  'x202',
#  'y202',
#  'z202',
#  'v202',
#  'x203',
#  'y203',
#  'z203',
#  'v203',
#  'x204',
#  'y204',
#  'z204',
#  'v204',
#  'x205',
#  'y205',
#  'z205',
#  'v205',
#  'x206',
#  'y206',
#  'z206',
#  'v206',
#  'x207',
#  'y207',
#  'z207',
#  'v207',
#  'x208',
#  'y208',
#  'z208',
#  'v208',
#  'x209',
#  'y209',
#  'z209',
#  'v209',
#  'x210',
#  'y210',
#  'z210',
#  'v210',
#  'x211',
#  'y211',
#  'z211',
#  'v211',
#  'x212',
#  'y212',
#  'z212',
#  'v212',
#  'x213',
#  'y213',
#  'z213',
#  'v213',
#  'x214',
#  'y214',
#  'z214',
#  'v214',
#  'x215',
#  'y215',
#  'z215',
#  'v215',
#  'x216',
#  'y216',
#  'z216',
#  'v216',
#  'x217',
#  'y217',
#  'z217',
#  'v217',
#  'x218',
#  'y218',
#  'z218',
#  'v218',
#  'x219',
#  'y219',
#  'z219',
#  'v219',
#  'x220',
#  'y220',
#  'z220',
#  'v220',
#  'x221',
#  'y221',
#  'z221',
#  'v221',
#  'x222',
#  'y222',
#  'z222',
#  'v222',
#  'x223',
#  'y223',
#  'z223',
#  'v223',
#  'x224',
#  'y224',
#  'z224',
#  'v224',
#  'x225',
#  'y225',
#  'z225',
#  'v225',
#  'x226',
#  'y226',
#  'z226',
#  'v226',
#  'x227',
#  'y227',
#  'z227',
#  'v227',
#  'x228',
#  'y228',
#  'z228',
#  'v228',
#  'x229',
#  'y229',
#  'z229',
#  'v229',
#  'x230',
#  'y230',
#  'z230',
#  'v230',
#  'x231',
#  'y231',
#  'z231',
#  'v231',
#  'x232',
#  'y232',
#  'z232',
#  'v232',
#  'x233',
#  'y233',
#  'z233',
#  'v233',
#  'x234',
#  'y234',
#  'z234',
#  'v234',
#  'x235',
#  'y235',
#  'z235',
#  'v235',
#  'x236',
#  'y236',
#  'z236',
#  'v236',
#  'x237',
#  'y237',
#  'z237',
#  'v237',
#  'x238',
#  'y238',
#  'z238',
#  'v238',
#  'x239',
#  'y239',
#  'z239',
#  'v239',
#  'x240',
#  'y240',
#  'z240',
#  'v240',
#  'x241',
#  'y241',
#  'z241',
#  'v241',
#  'x242',
#  'y242',
#  'z242',
#  'v242',
#  'x243',
#  'y243',
#  'z243',
#  'v243',
#  'x244',
#  'y244',
#  'z244',
#  'v244',
#  'x245',
#  'y245',
#  'z245',
#  'v245',
#  'x246',
#  'y246',
#  'z246',
#  'v246',
#  'x247',
#  'y247',
#  'z247',
#  'v247',
#  'x248',
#  'y248',
#  'z248',
#  'v248',
#  'x249',
#  'y249',
#  'z249',
#  'v249',
#  'x250',
#  'y250',
#  'z250',
#  ...]

# %%
import csv
with open('coordinate.csv', 'w', newline='') as csvfile:
    # Create a CSV writer object
    csvwriter = csv.writer(csvfile)
    
    # Write the column headers
    csvwriter.writerow(landmarks)

# %%
class_name = "happy"

# %%
cap = cv2.VideoCapture(0)
# Initiate holistic model
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    
    while cap.isOpened():
        ret, frame = cap.read()
        
        # Recolor Feed
        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        image.flags.writeable = False        
        
        # Make Detections
        results = holistic.process(image)
        # face_landmarks, pose_landmarks, left_hand_landmarks, right_hand_landmarks
        
        # Recolor image back to BGR for rendering
        image.flags.writeable = True   
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
        
        # 1. Draw face landmarks
        mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACEMESH_TESSELATION, 
                                 mp_drawing.DrawingSpec(color=(80,110,10), thickness=1, circle_radius=1),
                                 mp_drawing.DrawingSpec(color=(80,256,121), thickness=1, circle_radius=1)
                                 )
        
        # 2. Right hand
        mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(80,22,10), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(80,44,121), thickness=2, circle_radius=2)
                                 )

        # 3. Left Hand
        mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(121,22,76), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(121,44,250), thickness=2, circle_radius=2)
                                 )

        # 4. Pose Detections
        mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2)
                                 )
        
        # Export coordinates
        try:
            # Extract Pose landmarks
            pose = results.pose_landmarks.landmark
            pose_row = list(np.array([[landmark.x, landmark.y, landmark.z, landmark.visibility] for landmark in pose]).flatten())
            
            # Extract Face landmarks
            face = results.face_landmarks.landmark
            face_row = list(np.array([[landmark.x, landmark.y, landmark.z, landmark.visibility] for landmark in face]).flatten())
            
            # Concate rows
            row = pose_row+face_row
            
            # Append class name 
            row.insert(0, class_name)
            
            # Export to CSV
            with open('coordinate.csv', mode='a', newline='') as f:
                csv_writer = csv.writer(f, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
                csv_writer.writerow(row) 
            
        except:
            pass
                        
        cv2.imshow('Happy Webcam', image)

        if cv2.waitKey(10) & 0xFF == ord('q'):
            break

cap.release()
cv2.destroyAllWindows()

# %%
class_name = "sad"

# %%
cap = cv2.VideoCapture(0)
# Initiate holistic model
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    
    while cap.isOpened():
        ret, frame = cap.read()
        
        # Recolor Feed
        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        image.flags.writeable = False        
        
        # Make Detections
        results = holistic.process(image)
        # face_landmarks, pose_landmarks, left_hand_landmarks, right_hand_landmarks
        
        # Recolor image back to BGR for rendering
        image.flags.writeable = True   
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
        
        # 1. Draw face landmarks
        mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACEMESH_TESSELATION, 
                                 mp_drawing.DrawingSpec(color=(80,110,10), thickness=1, circle_radius=1),
                                 mp_drawing.DrawingSpec(color=(80,256,121), thickness=1, circle_radius=1)
                                 )
        
        # 2. Right hand
        mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(80,22,10), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(80,44,121), thickness=2, circle_radius=2)
                                 )

        # 3. Left Hand
        mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(121,22,76), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(121,44,250), thickness=2, circle_radius=2)
                                 )

        # 4. Pose Detections
        mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2)
                                 )
        
        # Export coordinates
        try:
            # Extract Pose landmarks
            pose = results.pose_landmarks.landmark
            pose_row = list(np.array([[landmark.x, landmark.y, landmark.z, landmark.visibility] for landmark in pose]).flatten())
            
            # Extract Face landmarks
            face = results.face_landmarks.landmark
            face_row = list(np.array([[landmark.x, landmark.y, landmark.z, landmark.visibility] for landmark in face]).flatten())
            
            # Concate rows
            row = pose_row+face_row
            
            # Append class name 
            row.insert(0, class_name)
            
            # Export to CSV
            with open('coordinate.csv', mode='a', newline='') as f:
                csv_writer = csv.writer(f, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
                csv_writer.writerow(row) 
            
        except:
            pass
                        
        cv2.imshow('Happy Webcam', image)

        if cv2.waitKey(10) & 0xFF == ord('q'):
            break

cap.release()
cv2.destroyAllWindows()

# %%
class_name = "victory"

# %%
cap = cv2.VideoCapture(0)
# Initiate holistic model
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    
    while cap.isOpened():
        ret, frame = cap.read()
        
        # Recolor Feed
        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        image.flags.writeable = False        
        
        # Make Detections
        results = holistic.process(image)
        # face_landmarks, pose_landmarks, left_hand_landmarks, right_hand_landmarks
        
        # Recolor image back to BGR for rendering
        image.flags.writeable = True   
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
        
        # 1. Draw face landmarks
        mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACEMESH_TESSELATION, 
                                 mp_drawing.DrawingSpec(color=(80,110,10), thickness=1, circle_radius=1),
                                 mp_drawing.DrawingSpec(color=(80,256,121), thickness=1, circle_radius=1)
                                 )
        
        # 2. Right hand
        mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(80,22,10), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(80,44,121), thickness=2, circle_radius=2)
                                 )

        # 3. Left Hand
        mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(121,22,76), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(121,44,250), thickness=2, circle_radius=2)
                                 )

        # 4. Pose Detections
        mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2)
                                 )
        
        # Export coordinates
        try:
            # Extract Pose landmarks
            pose = results.pose_landmarks.landmark
            pose_row = list(np.array([[landmark.x, landmark.y, landmark.z, landmark.visibility] for landmark in pose]).flatten())
            
            # Extract Face landmarks
            face = results.face_landmarks.landmark
            face_row = list(np.array([[landmark.x, landmark.y, landmark.z, landmark.visibility] for landmark in face]).flatten())
            
            # Concate rows
            row = pose_row+face_row
            
            # Append class name 
            row.insert(0, class_name)
            
            # Export to CSV
            with open('coordinate.csv', mode='a', newline='') as f:
                csv_writer = csv.writer(f, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
                csv_writer.writerow(row) 
            
        except:
            pass
                        
        cv2.imshow('Happy Webcam', image)

        if cv2.waitKey(10) & 0xFF == ord('q'):
            break

cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# # Train Custom Data Using Scikit learn

# %% [markdown]
# ## Split data into train, test

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('coordinate.csv')

# %%
df.head()
# Out:
#    class        x1        y1        z1        v1        x2        y2  \
# 0  happy  0.486905  0.912586 -1.439311  0.989635  0.525232  0.818816
# 1  happy  0.487925  0.919590 -1.572334  0.989678  0.527487  0.824485
# 2  happy  0.488317  0.926219 -1.645580  0.990424  0.531169  0.830586
# 3  happy  0.488517  0.930867 -1.608879  0.991119  0.532236  0.835535
# 4  happy  0.488647  0.930607 -1.309738  0.991223  0.532260  0.835323
#
#          z2        v2        x3  ...      z499  v499      x500      y500  \
# 0 -1.337016  0.990564  0.550895  ... -0.024750   0.0  0.567587  0.802648
# 1 -1.498890  0.990552  0.553234  ... -0.026191   0.0  0.575689  0.816272
# 2 -1.558532  0.991229  0.557190  ... -0.027124   0.0  0.571549  0.827423
# 3 -1.521589  0.991870  0.558391  ... -0.027620   0.0  0.570485  0.822928
# 4 -1.220953  0.991927  0.558405  ... -0.020966   0.0  0.573916  0.810485
#
#        z500  v500      x501      y501      z501  v501
# 0 -0.000200   0.0  0.574644  0.794113 -0.000250   0.0
# 1 -0.003308   0.0  0.582750  0.808482 -0.003637   0.0
# 2 -0.005993   0.0  0.578776  0.819000 -0.006188   0.0
# 3 -0.007287   0.0  0.577433  0.815350 -0.007719   0.0
# 4  0.003778   0.0  0.580517  0.804250  0.003624   0.0
#
# [5 rows x 2005 columns]

# %%
df.tail()
# Out:
#        class        x1        y1        z1        v1        x2        y2  \
# 372  victory  0.706182  0.415685 -0.698752  0.999928  0.719613  0.361621
# 373  victory  0.754120  0.385805 -0.799724  0.999884  0.768118  0.329990
# 374  victory  0.788687  0.363532 -0.742969  0.999857  0.804626  0.306018
# 375  victory  0.809323  0.333065 -1.101112  0.998783  0.828868  0.278057
# 376  victory  0.785581  0.305125 -1.030887  0.998586  0.808573  0.249017
#
#            z2        v2        x3  ...      z499  v499      x500      y500  \
# 372 -0.628298  0.999905  0.734176  ...  0.002409   0.0  0.770139  0.340672
# 373 -0.716371  0.999826  0.784218  ... -0.001415   0.0  0.818696  0.315521
# 374 -0.660203  0.999786  0.819623  ... -0.000327   0.0  0.850378  0.302846
# 375 -1.019158  0.998120  0.846293  ...  0.000620   0.0  0.870128  0.273141
# 376 -0.947972  0.997488  0.821557  ... -0.001630   0.0  0.832869  0.253945
#
#          z500  v500      x501      y501      z501  v501
# 372  0.028161   0.0  0.774021  0.336273  0.029415   0.0
# 373  0.021108   0.0  0.822426  0.311111  0.022063   0.0
# 374  0.024636   0.0  0.854563  0.297741  0.025796   0.0
# 375  0.025639   0.0  0.874573  0.267596  0.026825   0.0
# 376  0.023428   0.0  0.837512  0.248242  0.024548   0.0
#
# [5 rows x 2005 columns]

# %%
df[df["class"] == "sad"]
# Out:
#     class        x1        y1        z1        v1        x2        y2  \
# 92    sad  0.591363  0.929608 -1.240289  0.997477  0.622031  0.853073
# 93    sad  0.593085  0.926880 -1.241374  0.996922  0.623924  0.845572
# 94    sad  0.593300  0.921260 -1.286165  0.996084  0.625324  0.835768
# 95    sad  0.595019  0.900357 -1.188454  0.996194  0.627779  0.813677
# 96    sad  0.595780  0.883896 -1.209482  0.996200  0.629082  0.793803
# ..    ...       ...       ...       ...       ...       ...       ...
# 216   sad  0.773432  0.748601 -1.746229  0.998209  0.806057  0.655147
# 217   sad  0.792752  0.754926 -1.695421  0.998170  0.823544  0.664255
# 218   sad  0.805050  0.762093 -1.832899  0.998257  0.835330  0.672710
# 219   sad  0.808452  0.764735 -1.816931  0.998328  0.838345  0.676441
# 220   sad  0.810091  0.762590 -1.803557  0.998370  0.842409  0.674457
#
#            z2        v2        x3  ...      z499  v499      x500      y500  \
# 92  -1.141580  0.997429  0.642852  ... -0.013049   0.0  0.660374  0.845942
# 93  -1.141992  0.996982  0.645289  ... -0.013872   0.0  0.678313  0.815433
# 94  -1.200036  0.996350  0.647113  ... -0.012353   0.0  0.679592  0.807421
# 95  -1.095490  0.996394  0.650241  ... -0.012891   0.0  0.686469  0.791716
# 96  -1.124179  0.996347  0.652561  ... -0.016414   0.0  0.689395  0.780368
# ..        ...       ...       ...  ...       ...   ...       ...       ...
# 216 -1.614157  0.998102  0.829247  ... -0.005018   0.0  0.869814  0.683578
# 217 -1.554192  0.998021  0.846221  ... -0.005050   0.0  0.877591  0.694947
# 218 -1.688386  0.998098  0.857717  ... -0.005896   0.0  0.889583  0.701404
# 219 -1.672449  0.998155  0.860894  ... -0.007353   0.0  0.890014  0.701395
# 220 -1.662024  0.998204  0.865888  ... -0.002505   0.0  0.897810  0.689014
#
#          z500  v500      x501      y501      z501  v501
# 92   0.016844   0.0  0.667134  0.837079  0.017547   0.0
# 93   0.013785   0.0  0.684980  0.808190  0.014069   0.0
# 94   0.017162   0.0  0.686249  0.800945  0.017751   0.0
# 95   0.016530   0.0  0.693225  0.784454  0.017185   0.0
# 96   0.015004   0.0  0.696309  0.773610  0.015708   0.0
# ..        ...   ...       ...       ...       ...   ...
# 216  0.036895   0.0  0.876747  0.677273  0.038858   0.0
# 217  0.038590   0.0  0.884784  0.687797  0.040844   0.0
# 218  0.040190   0.0  0.897041  0.694331  0.042556   0.0
# 219  0.038240   0.0  0.897246  0.694402  0.040528   0.0
# 220  0.045141   0.0  0.904988  0.682594  0.047600   0.0
#
# [129 rows x 2005 columns]

# %%
y = df["class"]
X = df.drop(columns= "class", axis=1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state= 50)

# %% [markdown]
# ## Training with Classification model

# %%
from sklearn.pipeline import make_pipeline 
from sklearn.preprocessing import StandardScaler 
from sklearn.linear_model import LogisticRegression, RidgeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier

# %%
pipelines = {
    'lr':make_pipeline(StandardScaler(), LogisticRegression(max_iter=400)),
    'rc':make_pipeline(StandardScaler(), RidgeClassifier()),
    'rf':make_pipeline(StandardScaler(), RandomForestClassifier()),
    'gb':make_pipeline(StandardScaler(), GradientBoostingClassifier()),
}

# %%
fit_models = {}
for algo, pipeline in pipelines.items():
    model = pipeline.fit(X_train, y_train)
    fit_models[algo] = model

# %%
for key , value in fit_models.items():
    print(f"Algorithm: {key}")
    prediction = value.predict(X_test)
    print(f"Prediction: {prediction}")
# Out:
# Algorithm: lr
# Prediction: ['sad' 'happy' 'sad' 'victory' 'sad' 'happy' 'victory' 'victory' 'sad'
#  'victory' 'sad' 'happy' 'victory' 'victory' 'happy' 'happy' 'sad' 'sad'
#  'happy' 'sad' 'happy' 'victory' 'sad' 'happy' 'sad' 'victory' 'happy'
#  'happy' 'victory' 'victory' 'victory' 'victory' 'sad' 'victory' 'sad'
#  'happy' 'victory' 'victory' 'sad' 'sad' 'victory' 'sad' 'sad' 'victory'
#  'sad' 'victory' 'happy' 'sad' 'sad' 'happy' 'sad' 'happy' 'sad' 'victory'
#  'sad' 'victory' 'happy' 'victory' 'happy' 'sad' 'victory' 'victory'
#  'victory' 'happy' 'happy' 'victory' 'sad' 'happy' 'victory' 'sad' 'happy'
#  'happy' 'sad' 'victory' 'sad' 'victory' 'happy' 'happy' 'happy' 'sad'
#  'sad' 'sad' 'victory' 'victory' 'victory' 'sad' 'sad' 'victory' 'sad'
#  'sad' 'victory' 'victory' 'victory' 'victory' 'sad' 'victory' 'victory'
#  'happy' 'happy' 'happy' 'victory' 'sad' 'victory' 'sad' 'sad' 'sad'
#  'happy' 'happy' 'sad' 'sad' 'victory' 'happy' 'victory' 'happy']
# Algorithm: rc
# Prediction: ['sad' 'happy' 'sad' 'victory' 'sad' 'happy' 'victory' 'victory' 'sad'
#  'victory' 'sad' 'happy' 'victory' 'victory' 'happy' 'happy' 'sad' 'sad'
#  'happy' 'sad' 'happy' 'victory' 'sad' 'happy' 'sad' 'victory' 'happy'
#  'happy' 'victory' 'victory' 'victory' 'victory' 'sad' 'victory' 'sad'
#  'happy' 'victory' 'victory' 'sad' 'sad' 'victory' 'sad' 'sad' 'victory'
#  'sad' 'victory' 'happy' 'sad' 'sad' 'happy' 'sad' 'happy' 'sad' 'victory'
#  'sad' 'victory' 'happy' 'victory' 'happy' 'sad' 'victory' 'victory'
#  'victory' 'happy' 'happy' 'victory' 'sad' 'happy' 'victory' 'sad' 'happy'
#  'happy' 'sad' 'victory' 'sad' 'victory' 'happy' 'happy' 'happy' 'sad'
#  'sad' 'sad' 'victory' 'victory' 'victory' 'sad' 'sad' 'victory' 'sad'
#  'sad' 'victory' 'victory' 'victory' 'victory' 'sad' 'victory' 'victory'
#  'happy' 'happy' 'happy' 'victory' 'sad' 'victory' 'sad' 'sad' 'sad'
#  'happy' 'happy' 'sad' 'sad' 'victory' 'happy' 'victory' 'happy']
# Algorithm: rf
# Prediction: ['sad' 'happy' 'sad' 'victory' 'sad' 'happy' 'victory' 'victory' 'sad'
#  'victory' 'sad' 'happy' 'victory' 'victory' 'happy' 'happy' 'sad' 'sad'
#  'happy' 'sad' 'happy' 'victory' 'sad' 'happy' 'sad' 'victory' 'victory'
#  'happy' 'victory' 'victory' 'victory' 'victory' 'sad' 'victory' 'sad'
#  'victory' 'victory' 'victory' 'sad' 'sad' 'victory' 'sad' 'sad' 'victory'
#  'sad' 'victory' 'happy' 'sad' 'sad' 'happy' 'sad' 'happy' 'sad' 'victory'
#  'sad' 'victory' 'happy' 'victory' 'happy' 'sad' 'victory' 'victory'
#  'victory' 'happy' 'happy' 'victory' 'sad' 'happy' 'victory' 'sad' 'happy'
#  'happy' 'sad' 'victory' 'sad' 'victory' 'happy' 'happy' 'happy' 'sad'
#  'sad' 'sad' 'victory' 'victory' 'victory' 'sad' 'sad' 'victory' 'sad'
#  'sad' 'victory' 'victory' 'victory' 'victory' 'sad' 'victory' 'victory'
#  'happy' 'happy' 'happy' 'victory' 'sad' 'victory' 'sad' 'sad' 'sad'
#  'happy' 'happy' 'sad' 'sad' 'victory' 'happy' 'victory' 'happy']
# Algorithm: gb
# Prediction: ['sad' 'happy' 'sad' 'victory' 'sad' 'happy' 'victory' 'victory' 'sad'
#  'victory' 'sad' 'happy' 'victory' 'victory' 'happy' 'happy' 'sad' 'sad'
#  'happy' 'sad' 'happy' 'victory' 'sad' 'happy' 'sad' 'victory' 'happy'
#  'happy' 'victory' 'victory' 'victory' 'victory' 'sad' 'victory' 'sad'
#  'happy' 'victory' 'victory' 'sad' 'sad' 'victory' 'sad' 'sad' 'victory'
#  'sad' 'victory' 'happy' 'sad' 'sad' 'happy' 'sad' 'happy' 'sad' 'victory'
#  'sad' 'victory' 'happy' 'victory' 'happy' 'sad' 'victory' 'victory'
#  'victory' 'happy' 'happy' 'victory' 'sad' 'happy' 'victory' 'sad' 'sad'
#  'happy' 'sad' 'victory' 'sad' 'victory' 'happy' 'happy' 'happy' 'sad'
#  'sad' 'sad' 'victory' 'victory' 'victory' 'sad' 'sad' 'victory' 'sad'
#  'sad' 'victory' 'victory' 'victory' 'victory' 'sad' 'victory' 'victory'
#  'happy' 'happy' 'happy' 'victory' 'sad' 'victory' 'sad' 'sad' 'sad'
#  'happy' 'happy' 'sad' 'sad' 'victory' 'happy' 'victory' 'happy']

# %% [markdown]
# ## Evaluation the models

# %%
from sklearn.metrics import accuracy_score # Accuracy metrics 
import pickle

# %%
for algo , model in fit_models.items():
    prediction = model.predict(X_test)
    accuracy = accuracy_score(y_test, prediction)
    print(f"Algorithm: {algo} , Accuracy: {accuracy}")
# Out:
# Algorithm: lr , Accuracy: 1.0
# Algorithm: rc , Accuracy: 1.0
# Algorithm: rf , Accuracy: 0.9824561403508771
# Algorithm: gb , Accuracy: 0.9912280701754386

# %%
# Serializing the object data
with open('body_language.pkl', 'wb') as f:
    pickle.dump(fit_models['lr'], f)

# %% [markdown]
# # Make Detection with model

# %%
with open('body_language.pkl', 'rb') as f:
    model = pickle.load(f)
model
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('logisticregression', LogisticRegression(max_iter=400))])

# %%
cap = cv2.VideoCapture(0)
# Initiate holistic model
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    
    while cap.isOpened():
        ret, frame = cap.read()
        
        # Recolor Feed
        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        image.flags.writeable = False        
        
        # Make Detections
        results = holistic.process(image)
        # print(results.face_landmarks)
        
        # face_landmarks, pose_landmarks, left_hand_landmarks, right_hand_landmarks
        
        # Recolor image back to BGR for rendering
        image.flags.writeable = True   
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
        
        # 1. Draw face landmarks
        mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACEMESH_TESSELATION, 
                                 mp_drawing.DrawingSpec(color=(80,110,10), thickness=1, circle_radius=1),
                                 mp_drawing.DrawingSpec(color=(80,256,121), thickness=1, circle_radius=1)
                                 )
        
        # 2. Right hand
        mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(80,22,10), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(80,44,121), thickness=2, circle_radius=2)
                                 )

        # 3. Left Hand
        mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(121,22,76), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(121,44,250), thickness=2, circle_radius=2)
                                 )

        # 4. Pose Detections
        mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2)
                                 )
        # Export coordinates
        try:
            # Extract Pose landmarks
            pose = results.pose_landmarks.landmark
            pose_row = list(np.array([[landmark.x, landmark.y, landmark.z, landmark.visibility] for landmark in pose]).flatten())
            
            # Extract Face landmarks
            face = results.face_landmarks.landmark
            face_row = list(np.array([[landmark.x, landmark.y, landmark.z, landmark.visibility] for landmark in face]).flatten())
            
            # Concate rows
            row = pose_row+face_row
            
#             # Append class name 
#             row.insert(0, class_name)
            
#             # Export to CSV
#             with open('coords.csv', mode='a', newline='') as f:
#                 csv_writer = csv.writer(f, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
#                 csv_writer.writerow(row) 

            # Make Detections
            X = pd.DataFrame([row])
            body_language_class = model.predict(X)[0]
            body_language_prob = model.predict_proba(X)[0]
            print(body_language_class, body_language_prob)
            
            # Grab ear coords
            coords = tuple(np.multiply(
                            np.array(
                                (results.pose_landmarks.landmark[mp_holistic.PoseLandmark.LEFT_EAR].x, 
                                 results.pose_landmarks.landmark[mp_holistic.PoseLandmark.LEFT_EAR].y))
                        , [640,480]).astype(int))
            
            cv2.rectangle(image, 
                          (coords[0], coords[1]+5), 
                          (coords[0]+len(body_language_class)*20, coords[1]-30), 
                          (245, 117, 16), -1)
            cv2.putText(image, body_language_class, coords, 
                        cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
            
            # Get status box
            cv2.rectangle(image, (0,0), (250, 60), (245, 117, 16), -1)
            
            # Display Class
            cv2.putText(image, 'CLASS'
                        , (95,12), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 0), 1, cv2.LINE_AA)
            cv2.putText(image, body_language_class.split(' ')[0]
                        , (90,40), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
            
            # Display Probabilityq
            cv2.putText(image, 'PROB'
                        , (15,12), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 0), 1, cv2.LINE_AA)
            cv2.putText(image, str(round(body_language_prob[np.argmax(body_language_prob)],2))
                        , (10,40), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
            
        except:
            pass
                        
        cv2.imshow('Raw Webcam Feed', image)

        if cv2.waitKey(10) & 0xFF == ord('q'):
            break

cap.release()
cv2.destroyAllWindows()
# Out:
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# happy [9.99429055e-01 4.03708856e-04 1.67236445e-04]
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# happy [9.93897609e-01 5.76574630e-03 3.36645096e-04]
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# happy [0.9664438  0.03013828 0.00341793]
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# happy [0.91122365 0.08166221 0.00711414]
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# sad [0.2783686  0.66211292 0.05951848]
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# sad [0.33201306 0.64494529 0.02304165]
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# sad [0.40668551 0.58001283 0.01330165]
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# sad [0.36911155 0.61700678 0.01388168]
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# sad [0.37831117 0.61349395 0.00819488]
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# sad [0.34623025 0.65009703 0.00367272]
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# sad [0.43675485 0.56117672 0.00206843]
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# happy [0.74173949 0.25747826 0.00078224]
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# happy [9.03137792e-01 9.68235610e-02 3.86467501e-05]
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# happy [9.67927944e-01 3.19860878e-02 8.59677277e-05]
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# sad [0.45683659 0.53957488 0.00358853]
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# sad [0.02396494 0.97296161 0.00307344]
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# sad [0.25844003 0.73396979 0.00759018]
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# sad [0.10828208 0.88161681 0.01010111]
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# sad [0.05401365 0.93706356 0.00892279]
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# sad [0.030297   0.96408495 0.00561805]
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# sad [0.02829011 0.96174097 0.00996893]
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# sad [0.04227459 0.9491066  0.00861882]
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# sad [0.11269802 0.88159343 0.00570856]
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# sad [0.07574204 0.91895602 0.00530194]
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# sad [0.05534397 0.9396399  0.00501614]
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# sad [0.07199717 0.92332864 0.0046742 ]
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# sad [0.07222007 0.92130692 0.00647301]
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# sad [0.10711597 0.8109453  0.08193873]
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# sad [0.10960696 0.59688859 0.29350444]
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# sad [0.05141818 0.48281206 0.46576976]
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# victory [0.0083117  0.48218885 0.50949946]
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# victory [0.00075369 0.3682727  0.63097361]
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# sad [3.03406517e-05 5.28790616e-01 4.71179043e-01]
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# sad [7.12799289e-05 5.42941138e-01 4.56987582e-01]
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# victory [1.03587809e-04 2.39927643e-01 7.59968769e-01]
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# victory [0.00168002 0.20240369 0.79591628]
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# victory [0.0024996  0.14159389 0.85590651]
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# victory [0.0012808  0.19011642 0.80860277]
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# victory [0.00148273 0.15095537 0.8475619 ]
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# victory [0.00224394 0.150735   0.84702106]
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# victory [0.00265113 0.12272442 0.87462445]
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# victory [0.00107813 0.14310467 0.85581719]
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# victory [0.00096085 0.144992   0.85404715]
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# victory [5.74656946e-04 9.67055392e-02 9.02719804e-01]
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# sad [0.00752633 0.57639487 0.4160788 ]
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# sad [0.00538154 0.57977909 0.41483937]
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# sad [0.00680523 0.60429075 0.38890402]
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# sad [0.00720338 0.533221   0.45957563]
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# sad [0.03109314 0.59641392 0.37249294]
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# sad [0.06799513 0.61831527 0.31368961]
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# sad [0.09088475 0.6746944  0.23442085]
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# sad [0.16278258 0.75815452 0.0790629 ]
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# sad [0.35768938 0.60477611 0.03753451]
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# sad [0.16990123 0.78263992 0.04745885]
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# sad [0.29639408 0.67012351 0.0334824 ]
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# sad [0.27548336 0.68451307 0.04000357]
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# sad [0.24226867 0.70939613 0.0483352 ]
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# sad [0.14443664 0.81737491 0.03818846]
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# sad [0.14555739 0.82010143 0.03434118]
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# sad [0.17831452 0.78608401 0.03560146]
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# sad [0.03257712 0.95483574 0.01258714]
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# sad [0.04516177 0.93922071 0.01561752]
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# sad [0.06049171 0.92315071 0.01635759]
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# sad [0.06808052 0.91344266 0.01847682]
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# sad [0.08610883 0.8933921  0.02049907]
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# sad [0.07086224 0.91601697 0.01312079]
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# sad [0.06996659 0.91753093 0.01250248]
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# sad [0.08764806 0.90319673 0.00915522]
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# sad [0.06076843 0.92811903 0.01111254]
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# sad [0.07017893 0.92017865 0.00964243]
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# sad [0.0794252  0.91106748 0.00950732]
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# sad [0.06520825 0.92697775 0.00781399]
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# sad [0.06607129 0.92650092 0.00742778]
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# sad [0.0545342  0.93564351 0.00982229]
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# sad [0.05348926 0.93830047 0.00821026]
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# sad [0.05051071 0.93961428 0.00987501]
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# sad [0.20741891 0.78213675 0.01044434]
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# sad [0.11059502 0.57382958 0.3155754 ]
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# victory [0.08039779 0.24986277 0.66973943]
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# victory [0.05370645 0.27466437 0.67162918]
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# victory [0.05990706 0.14564118 0.79445177]
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# victory [0.0297479  0.18439281 0.78585929]
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# victory [0.02307658 0.16613898 0.81078444]
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# victory [0.02709438 0.21444707 0.75845855]
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# victory [0.00707493 0.11675786 0.87616721]
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# victory [0.00195481 0.05521017 0.94283502]
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# victory [0.00189461 0.04984001 0.94826538]
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# victory [0.00995576 0.04229787 0.94774637]
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# sad [0.04635149 0.65788997 0.29575854]
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# sad [0.05610891 0.77133463 0.17255646]
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# sad [0.027981   0.84786948 0.12414952]
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# sad [0.03515693 0.90725518 0.05758789]
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# sad [0.02934723 0.86050401 0.11014876]
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# sad [0.02922316 0.76283219 0.20794465]
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# sad [0.03542982 0.74814125 0.21642893]
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# sad [0.05243653 0.84974349 0.09781998]
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# sad [0.04137833 0.87784198 0.08077968]
